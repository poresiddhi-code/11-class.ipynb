# %% [markdown]
# <a href="https://colab.research.google.com/github/poresiddhi-code/11-class.ipynb/blob/main/11_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Class and Object

# %% [markdown]
# One of the most important cocepts in python and many other programming languages
#
# We'll start with an example

# %% [markdown]
# Basic Example

# %%
class Employee:            # We are defining a class named Employee (class has to be in lowercase)
    name = "John"          # name and age are called attributes of the class
    age = 26

emp = Employee()           # emp is an object of class
type(emp)                  # we can cross check the data type of emp (ignore the __main__ in output, it represents the current file)

# %% [markdown]
# Example

# %%
class Employee:            # We are defining a class named Employee (class has to be in lowercase)
    name = "Siddhi"          # name and age are called attributes of the class
    age = 24

emp = Employee()           # emp is an object of class
type(emp)                  # we can cross check the data type of emp (ignore the __main__ in output, it represents the current file)

# %%
from contextlib import redirect_stderr
class car:
  name = "bmw"
  color = "red"
emp = car()
type(emp)

# %% [markdown]
# Above, we have introduced three concepts - Class, Attribute and Object.
#
# Object is instance of Class
#
# Class represents an entity (in this case employee)
#
# Attributes are properties of such entity

# %%
# Object of a class can access attributes of the class
class Employee:            # We are defining a class named Employee (class has to be in lowercase)
    name = "John"          # name and age are called attributes of the class
    age = 26

emp = Employee()           # emp is an object of class
type(emp)
                 # we can cross check the data type of emp (ignore the __main__ in output, it represents the current file)
print(emp.name)
print(emp.age)

# %% [markdown]
# Example

# %%
print(emp.name)
print(emp.color)

# %% [markdown]
# Attributes and Methods
# Just like a class has attributes, it can also have methods

# %%
# Let's define one method
# Method is also part of class, so it should have the indentation as well

class Employee:
    name = "Sana"
    age = 26

    def hello(self):       # self is nothing but the object that is calling this function.
      print("Hello")

emp = Employee()
emp.hello()                 # when this is called, the emp object is passed as self above

# %% [markdown]
# Example

# %%
# Let's define one method
# Method is also part of class, so it should have the indentation as well

class Employee:
    name = "Siddhi"
    age = 24

    def hello(self):       # self is nothing but the object that is calling this function.
      print("ethereal")

emp = Employee()
emp.hello()                 # when this is called, the emp object is passed as self above

# %% [markdown]
# Think of class as something that represennts real life entiity such as Employee, Student, Product etc.
#
# And object is the actual example (instance) or that class

# %%
# The above code is correct, but we'd like to pass name and age when we create object.
# So this is how we'll modify the code

class Employee:
    def __init__(self, name, age):
        self.name = name
        self.age = age


    def details(self):
        print("Employee Name: ",  self.name)
        print("Employee Age: ", self.age)


emp1 = Employee("John", 26)         # creating object named emp1  --> the arguments are passed to init() automatically, and emp1 automatically gets name and age properties as passed
emp2 = Employee("Jane", 24)         # creating object named emp2  --> here also the arguments are passed to inti() without explicit calling

emp1.details()
emp2.details()

# %% [markdown]
# Example

# %%
# The above code is correct, but we'd like to pass name and age when we create object.
# So this is how we'll modify the code

class Employee:
    def __init__(self, name, age):
        self.name = name
        self.age = age


    def details(self):
        print("Employee Name: ",  self.name)
        print("Employee Age: ", self.age)


emp1 = Employee("siddhi", 26)         # creating object named emp1  --> the arguments are passed to init() automatically, and emp1 automatically gets name and age properties as passed
emp2 = Employee("om", 24)         # creating object named emp2  --> here also the arguments are passed to inti() without explicit calling

emp1.details()
emp2.details()

# %% [markdown]
# First, just run the above example and try to figure out what's happening.
#
# init() is a special function inside class which gets executed when an object is defined (in our example object is defined when we said emp1 = and emp2 = )
#
# When the details() method executes, the self parameter references the emp1 object (same with emp2).
#
# Method names should contain lowercase with words separated by underscores as necessary to improve readability.
#
# Methods work in exactly the same way as simple functions, with one crucial exception: a method's first argument always receives the instance object.
#
# Those methods that do not take any arguments have at least the argument as self.

# %% [markdown]
# Some examples

# %%
class Student:
    def __init__(self, name):
        self.name = name         # the right side name is coming from the argument in the init(). While with the left side name we are defining a new property for the object and assigning value to that property with right side name

    def intro(self):
        print('Hi I am', self.name)

    def change_name(self, name):
        self.name = name

john = Student('john')

# access method
john.intro()

# access attribute
print(john.name)

# change name
john.change_name('JJOOHHNN')
john.intro()

# %% [markdown]
# Example

# %%
class Student:
    def __init__(self, name):
        self.name = name         # the right side name is coming from the argument in the init(). While with the left side name we are defining a new property for the object and assigning value to that property with right side name

    def intro(self):
        print('Hi I am', self.name)

    def change_name(self, name):
        self.name = name

john = Student('John')

# access method
john.intro()

# access attribute
print(john.name)

# change name
john.change_name('Riddhi')
john.intro()

# %%
class Rectangle:
    def __init__(self, length, width ):
        self.length = length
        self.width = width
    def area(self):
        print(f"Length - {self.length}, Width - {self.width}")
        return self.length * self.width

first = Rectangle(5,2)
print(first.area())

# %%
class Dog:
  def __init__(self, breed, age, color):
    self.breed = breed
    self.age = age
    self.color = color
  def details(self):
    print(f"Breed - {self.breed}, Age - {self.age}, Color - {self.age} ")

dog1 = Dog('Husky', 5, 'Blank')

dog1.details()

# %%
dog1.age

# %% [markdown]
# Use of Classes

# %% [markdown]
# Suppose the concept of class wasn't there.
#
# And suppose you want to write a program for a school which has 500 students. You need to store roll number, age, name, address of all these students.
#
# So how would you manage variables for these students?
#
# One way would be to use 2000 variables
#
# (i.e. 4 variables for one student like - student1_roleno, student1_age, student1_name, student1_address,
#
# student2_rollno, and so on)
#
# As you can see, this is very inefficient and counter-productive
#
# Classes and objects allow us to store separate students' data separately and cohesively.

# %% [markdown]
# This much knowledge of classes is enough for now. You'll learn more on the go when you actually solve some problems.
